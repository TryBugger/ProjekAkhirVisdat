# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_pariwisata = pd.read_csv('dataset/tourism_with_id.csv')
df_pengunjung = pd.read_csv('dataset/user.csv')
df_rating = pd.read_csv('dataset/tourism_rating.csv')

# %%
df_pariwisata.sample(30)
# Out:
#      Place_Id                      Place_Name
# 421       422      Monumen Jalesveva Jayamahe  \
# 382       383                   Taman Tabanas
# 56         57          Taman Lapangan Banteng
# 180       181                   Pantai Sundak
# 213       214            Trans Studio Bandung
# 192       193                      Candi Sewu
# 427       428  Monumen Bambu Runcing Surabaya
# 366       367             Wisata Lereng Kelir
# 252       253       Selasar Sunaryo Art Space
# 402       403                Taman Barunawati
# 174       175            Museum Ullen Sentalu
# 304       305             Sunrise Point Cukul
# 329       330               Bandros City Tour
# 380       381              Tugu Muda Semarang
# 54         55            Klenteng Jin De Yuan
# 141       142                     Ledok Sambi
# 208       209                  Pantai Sanglen
# 172       173                 Pantai Nglambor
# 24         25               Pasar Tanah Abang
# ...

# %% [markdown]
# # Top 10 terbanyak dan tersedikit rating pariwisata masing-masing kota

# %%
kota = 'Jakarta'

df_pariwisata[df_pariwisata['City'] == kota].sort_values(by=['Rating'], ascending=False).reset_index(drop=True)
# Out:
#     Place_Id                 Place_Name
# 0         29  Wisata Kuliner Pecenongan  \
# 1         69            Freedom Library
# 2         14              Pulau Pelangi
# 3         49      Galeri Indonesia Kaya
# 4         23            Gereja Katedral
# ..       ...                        ...
# 79        50            Museum Joang 45
# 80        46           Pulau Semak Daun
# 81        25          Pasar Tanah Abang
# 82         8              Ocean Ecopark
# 83        12                 Pulau Pari
#
#                                           Description            Category
# 0   Pecenongan merupakan salah satu surga kuliner ...  Pusat Perbelanjaan  \
# 1   Freedom Library adalah perpustakaan buku yang ...              Budaya
# 2   Pulau Pelangi adalah sebuah pulau yang terleta...              Bahari
# 3   Galeri Indonesia Kaya (disingkat GIK) adalah r...              Budaya
# 4   Gereja Katedral Jakarta, atau bernama resmi Ge...       Tempat Ibadah
# ...

# %%
df_top10_pariwisata = df_pariwisata[df_pariwisata['City'] == kota].sort_values(by=['Rating'], ascending=False).reset_index(drop=True)
df_top10_pariwisata = pd.concat([df_top10_pariwisata.head(10), df_top10_pariwisata.tail(10)])

# %%
fig, ax = plt.subplots(1, 1, figsize=[20, 14])
green_gradient = np.linspace(0.4, 1, 10)[::-1]
red_gradient = np.linspace(0.4, 1, 10)

ax.bar(df_top10_pariwisata.loc[:10, 'Place_Name'], df_top10_pariwisata.loc[:10, 'Rating'], 
       color=plt.cm.Greens(green_gradient))
ax.bar(df_top10_pariwisata.loc[10:, 'Place_Name'], df_top10_pariwisata.loc[10:, 'Rating'], 
       color=plt.cm.Reds(red_gradient))

ax.tick_params(axis='x', labelrotation = -90)
