# %%
# !conda install -c conda-forge -y mscorefonts

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

# rc('font',**{'family':'sans-serif','sans-serif':['Lato']})
# plt.rcParams['font.family'] = ['sans-serif']
# plt.rcParams['font.sans-serif'] = ['Lato']

# %%
data_destination = pd.read_csv('dataset/tourism_with_id.csv')
df_pengunjung = pd.read_csv('dataset/user.csv')
df_rating = pd.read_csv('dataset/tourism_rating.csv')

# %%
data_destination.sample(5)
# Out:
#      Place_Id                   Place_Name
# 415       416             Keraton Surabaya  \
# 69         70        Perpustakaan Nasional
# 62         63  Museum Kebangkitan Nasional
# 88         89         De Mata Museum Jogja
# 47         48         Taman Ismail Marzuki
#
#                                            Description Category        City
# 415  Kawasan yang berjuluk Kampung Keraton ini terd...   Budaya    Surabaya  \
# 69   Perpustakaan Nasional adalah perpustakaan yang...   Budaya     Jakarta
# 62   Museum Kebangkitan Nasional (bahasa Inggris: M...   Budaya     Jakarta
# 88   Museum De Mata merupakan salah satu museum yan...   Budaya  Yogyakarta
# 47   Pusat Kesenian Jakarta Taman Ismail Marzuki ya...   Budaya     Jakarta
#
#      Price  Rating  Time_Minutes
# 415      0     4.4           NaN  \
# 69       0     4.7         240.0
# 62    2000     4.7          45.0
# 88   50000     4.4           NaN
# 47    5000     4.6           NaN
#
#                                           Coordinate       Lat        Long
# 415  {'lat': -7.256755299999998, 'lng': 112.7942203} -7.256755  112.794220  \
# 69   {'lat': -6.181291799999999, 'lng': 106.8268717} -6.181292  106.826872
# 62             {'lat': -6.178352, 'lng': 106.838094} -6.178352  106.838094
# 88   {'lat': -7.816315599999999, 'lng': 110.3871442} -7.816316  110.387144
# 47           {'lat': -6.1891586, 'lng': 106.8397738} -6.189159  106.839774
#
#      Unnamed: 11  Unnamed: 12
# 415          NaN          416
# 69           NaN           70
# 62           NaN           63
# 88           NaN           89
# 47           NaN           48

# %%
df_pengunjung.sample(5)
# Out:
#      User_Id                   Location  Age
# 92        93  Lampung, Sumatera Selatan   18
# 71        72         Tanggerang, Banten   19
# 212      213         Bekasi, Jawa Barat   20
# 207      208            Yogyakarta, DIY   27
# 260      261            Yogyakarta, DIY   38

# %%
df_rating.sample(5)
# Out:
#       User_Id  Place_Id  Place_Ratings
# 5552      168       357              1
# 10          1       103              3
# 6635      199       363              1
# 4889      148       154              1
# 3282      100       102              5

# %% [markdown]
# # Top 10 terbanyak dan tersedikit rating pariwisata masing-masing kota

# %%
kota = 'Jakarta'

data_destination[data_destination['City'] == kota].sort_values(by=['Rating'], ascending=False).reset_index(drop=True)
# Out:
#     Place_Id                 Place_Name
# 0         29  Wisata Kuliner Pecenongan  \
# 1         69            Freedom Library
# 2         14              Pulau Pelangi
# 3         49      Galeri Indonesia Kaya
# 4         23            Gereja Katedral
# ..       ...                        ...
# 79        50            Museum Joang 45
# 80        46           Pulau Semak Daun
# 81        25          Pasar Tanah Abang
# 82         8              Ocean Ecopark
# 83        12                 Pulau Pari
#
#                                           Description            Category
# 0   Pecenongan merupakan salah satu surga kuliner ...  Pusat Perbelanjaan  \
# 1   Freedom Library adalah perpustakaan buku yang ...              Budaya
# 2   Pulau Pelangi adalah sebuah pulau yang terleta...              Bahari
# 3   Galeri Indonesia Kaya (disingkat GIK) adalah r...              Budaya
# 4   Gereja Katedral Jakarta, atau bernama resmi Ge...       Tempat Ibadah
# ..                                                ...                 ...
# 79  Gedung Joang '45 atau Museum Joang 45 adalah s...              Budaya
# 80  Pulau Semak Daun merupakan salah satu pulau ya...              Bahari
# 81  Pasar Tanah Abang atau Pasar Sabtu dibangun ol...  Pusat Perbelanjaan
# 82  Ocean Ecopark Salah satu zona rekreasi Ancol y...       Taman Hiburan
# 83  Pulau Pari adalah sebuah pulau yang terletak d...              Bahari
#
#        City   Price  Rating  Time_Minutes
# 0   Jakarta       0     5.0           NaN  \
# 1   Jakarta       0     5.0           NaN
# 2   Jakarta  900000     4.8           NaN
# 3   Jakarta       0     4.8          90.0
# 4   Jakarta       0     4.8           NaN
# ..      ...     ...     ...           ...
# 79  Jakarta    2000     4.0           NaN
# 80  Jakarta   40000     4.0           NaN
# 81  Jakarta       0     4.0          45.0
# 82  Jakarta  180000     4.0           NaN
# 83  Jakarta  150000     4.0           NaN
#
#                                          Coordinate       Lat        Long
# 0   {'lat': -6.166788700000001, 'lng': 106.8265261} -6.166789  106.826526  \
# 1   {'lat': -6.202248200000001, 'lng': 106.8451968} -6.202248  106.845197
# 2               {'lat': -5.587055, 'lng': 106.5885} -5.587055  106.588500
# 3           {'lat': -6.1948499, 'lng': 106.8200607} -6.194850  106.820061
# 4    {'lat': -6.169225000000001, 'lng': 106.833063} -6.169225  106.833063
# ..                                              ...       ...         ...
# 79  {'lat': -6.186183799999998, 'lng': 106.8364761} -6.186184  106.836476
# 80  {'lat': -5.729671599999999, 'lng': 106.5714158} -5.729672  106.571416
# 81  {'lat': -6.189009599999999, 'lng': 106.8119312} -6.189010  106.811931
# 82  {'lat': -6.125801699999999, 'lng': 106.8363249} -6.125802  106.836325
# 83          {'lat': -5.9074328, 'lng': 106.5863989} -5.907433  106.586399
#
#     Unnamed: 11  Unnamed: 12
# 0           NaN           29
# 1           NaN           69
# 2           NaN           14
# 3           NaN           49
# 4           NaN           23
# ..          ...          ...
# 79          NaN           50
# 80          NaN           46
# 81          NaN           25
# 82          NaN            8
# 83          NaN           12
#
# [84 rows x 13 columns]

# %%
df_top10_pariwisata = data_destination[data_destination['City'] == kota].sort_values(by=['Rating'], ascending=False).reset_index(drop=True)
df_top10_pariwisata['Rating'].mean()
# Out:
# 4.488095238095238

# %%
fig, ax = plt.subplots(1, 1, figsize=[20, 14])
green_gradient = np.linspace(0.4, 1, 10)[::-1]
red_gradient = np.linspace(0.4, 1, 10)

ax.bar(df_top10_pariwisata[:10]['Place_Name'], df_top10_pariwisata[:10]['Rating'], 
       color=plt.cm.Greens(green_gradient), label='_nolegend_')
ax.bar(df_top10_pariwisata[-10:]['Place_Name'], df_top10_pariwisata[-10:]['Rating'], 
       color=plt.cm.Reds(red_gradient), label='_nolegend_')
ax.axhline(df_top10_pariwisata['Rating'].mean(), color='dodgerblue',
           linewidth=5, label='Rata-rata')
# sns.barplot(data=df_top10_pariwisata[:10], x='Place_Name', y='Rating', 
#             palette="dark:#5A9", ax=ax)

ax.tick_params(axis='x', labelrotation = -90)
ax.set_ylabel('Rating', fontsize=18)
ax.set_xlabel('Nama Pariwisata', fontsize=18)
ax.set_title('Daftar Pariwisata Berdasarkan Rating', fontsize=28)

ax.legend(fontsize=22)
plt.show()

# %% [markdown]
# # Top 10 terbanyak dan tersedikit rating pariwisata masing-masing kota

# %% [markdown]
# # Total Keseluruhan Rating Antar Kota

# %%
data_destination.head()
# Out:
#    Place_Id                         Place_Name
# 0         1                   Monumen Nasional  \
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta  \
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#     Price  Rating  Time_Minutes
# 0   20000     4.6          15.0  \
# 1       0     4.6          90.0
# 2  270000     4.6         360.0
# 3   10000     4.5           NaN
# 4   94000     4.5          60.0
#
#                                         Coordinate       Lat        Long
# 0          {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153  \
# 1  {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2  {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3  {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4             {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
#
#    Unnamed: 11  Unnamed: 12
# 0          NaN            1
# 1          NaN            2
# 2          NaN            3
# 3          NaN            4
# 4          NaN            5

# %%
data_kota_total_rating = data_destination.loc[:, ['City', 'Rating']].groupby('City').sum().reset_index()

fig, ax = plt.subplots(1, 1, figsize=[8, 6])
colors = ['steelblue' if (city == 'Jakarta') else 'lightgrey' for city in data_kota_total_rating['City']]

sns.barplot(data=data_kota_total_rating,
            x='City', y='Rating', palette=colors, 
            ax=ax)
# Out:
# <Axes: xlabel='City', ylabel='Rating'>

# %% [markdown]
# # Total Keseluruhan Rating Antar Kota

# %%
data_kategori_total_rating = data_destination.loc[:, ['Category', 'Rating']].groupby('Category').sum().sort_values(by='Rating', ascending=False).reset_index()
fig, ax = plt.subplots(1, 1, figsize=[12, 8])
colors = ['mediumseagreen'] + ['lightgrey']*(len(data_kategori_total_rating) - 2) + ['indianred']

sns.barplot(data=data_kategori_total_rating,
            x='Category', y='Rating', palette=colors, 
            ax=ax)
# Out:
# <Axes: xlabel='Category', ylabel='Rating'>

# %%
data_destination.head()
# Out:
#    Place_Id                         Place_Name
# 0         1                   Monumen Nasional  \
# 1         2                           Kota Tua
# 2         3                      Dunia Fantasi
# 3         4  Taman Mini Indonesia Indah (TMII)
# 4         5           Atlantis Water Adventure
#
#                                          Description       Category     City
# 0  Monumen Nasional atau yang populer disingkat d...         Budaya  Jakarta  \
# 1  Kota tua di Jakarta, yang juga bernama Kota Tu...         Budaya  Jakarta
# 2  Dunia Fantasi atau disebut juga Dufan adalah t...  Taman Hiburan  Jakarta
# 3  Taman Mini Indonesia Indah merupakan suatu kaw...  Taman Hiburan  Jakarta
# 4  Atlantis Water Adventure atau dikenal dengan A...  Taman Hiburan  Jakarta
#
#     Price  Rating  Time_Minutes
# 0   20000     4.6          15.0  \
# 1       0     4.6          90.0
# 2  270000     4.6         360.0
# 3   10000     4.5           NaN
# 4   94000     4.5          60.0
#
#                                         Coordinate       Lat        Long
# 0          {'lat': -6.1753924, 'lng': 106.8271528} -6.175392  106.827153  \
# 1  {'lat': -6.137644799999999, 'lng': 106.8171245} -6.137645  106.817125
# 2  {'lat': -6.125312399999999, 'lng': 106.8335377} -6.125312  106.833538
# 3  {'lat': -6.302445899999999, 'lng': 106.8951559} -6.302446  106.895156
# 4             {'lat': -6.12419, 'lng': 106.839134} -6.124190  106.839134
#
#    Unnamed: 11  Unnamed: 12
# 0          NaN            1
# 1          NaN            2
# 2          NaN            3
# 3          NaN            4
# 4          NaN            5
